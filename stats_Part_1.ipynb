# %% [markdown]
# ## MEASURE OF CENTRAL TENDANCY
# 1. MEAN
# 2. MEDIAN
# 3. MODE

# %%
ages=[23,24,32,45,23,24,54,34,45,56,67,34,100]

# %%
import numpy as np 
print(np.mean(ages))
# Out:
# 43.15384615384615

# %%
print(np.median(ages))
# Out:
# 34.0

# %%
import statistics as st

# %%
print("Median age: ", st.median(ages))
print("Mean age: ", st.mean(ages))
print("Mode age: ", st.mode(ages))
# Out:
# Median age:  34
# Mean age:  43.15384615384615
# Mode age:  23

# %%
import seaborn as sns

# %%
sns.boxplot(ages)
# Out:
# <Axes: >

# %% [markdown]
# ## 5. NUMBER SUMMARY

# %%
import numpy as np

# %%
q1,q3 = np.percentile(ages,[25,75])

# %%
print(f"q1 which is 25% is :: {q1} :: and q3 which is 75% is :: {q3} ::")
# Out:
# q1 which is 25% is :: 24.0 :: and q3 which is 75% is :: 54.0 ::

# %%
IQR = q3 - q1

# %%
## check outlier [lower bound and upper bound]
lower_bound = q1 - 1.5 * (IQR)
upper_bound = q3 + 1.5 * (IQR)

print(f"The lower bound is {lower_bound} and the upper bound is {upper_bound}")
# Out:
# The lower bound is -21.0 and the upper bound is 99.0

# %% [markdown]
# ## MEASURE OF DISPERSION
# 1. VARIANCE
# 2. STANDARD DEVIATION

# %%
statistics.variance(ages)
# Out:
# 493.97435897435895

# %%
np.var(ages,axis=0)
# Out:
# np.float64(455.9763313609467)

# %%
def variance(data):
    n = len(data)
    mean = sum(data) / n    ## find mean
    deviations = [(x - mean) ** 2 for x in data]    ## Find variance
    variance = sum(deviations) / n  ## if i use n-1 instead of n then it is sample variance if not then it is population variance
    return variance

# %%
variance(ages)
# Out:
# 455.97633136094674

# %%
def variance(data, ddof=0):
    n = len(data)
    ##Mean of the data
    mean = sum(data) / n
    ##Variance of the data
    deviations = [(x - mean) ** 2 for x in data]
    variance =sum(deviations) / (n-1)
    return variance

# %%
variance(ages,ddof=1)
# Out:
# 493.97435897435895

# %%
statistics.pvariance(ages)   ## population variance
# Out:
# 455.97633136094674

# %%
import math

# %%
math.sqrt(statistics.pvariance(ages))
# Out:
# 21.353602304083186

# %% [markdown]
# ## HISTOGRAM AND PDF

# %%
import seaborn as sns
sns.histplot(ages,kde=True)  ## kde is for kernel density means it is a smooth curve of the histogram that shows the distribution of the data
# Out:
# <Axes: ylabel='Count'>

# %%
df = sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(df["sepal_length"],kde=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(df["sepal_width"],kde=True)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(df["petal_length"],kde=True)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
## creatw  a normal distribution data
s= np.random.normal(0.5,0.2,1000)

# %%
s
# Out:
# array([ 0.2360147 ,  0.21107309,  0.77696048,  0.68113868,  0.50559773,
#         0.53877466,  0.2875553 ,  0.56184237,  0.59520669,  0.57767917,
#         0.31771005,  0.80665937,  0.6503844 ,  0.43251323,  0.5585328 ,
#         0.56128458,  1.03760402,  0.46893022,  0.33615248,  0.28114155,
#         0.57010188,  0.60833915,  0.58091324,  0.4684404 ,  0.77515629,
#         0.74160934,  0.42885863,  0.52299715,  0.07398014,  0.64523476,
#         0.51291912,  0.2493589 ,  0.66987075,  0.3369149 ,  0.41112703,
#         0.59344185,  0.68633452,  0.81305492,  0.26866232,  0.45703288,
#         0.44083749,  0.49708731,  0.39659175,  0.17833612,  0.16214138,
#         0.26018845,  0.59528007,  0.29007305,  0.67447715,  0.78519359,
#         0.38106115,  0.42026728,  0.5336771 ,  0.49864445,  0.23625074,
#         0.56164294,  0.18371338,  0.41667229,  0.74834544,  0.23245484,
#         0.30237466,  0.77956492,  0.58024875,  0.10708537,  0.71254509,
#         0.09595493,  0.51274554,  0.50394971,  0.44534394,  0.59179334,
#         0.54561033,  0.22384266,  0.81664163,  0.74337974,  0.51849492,
#         0.73359447,  0.64013611,  0.49135221,  0.99557284,  0.54362776,
#         0.67121441,  0.60812772,  0.38007362,  0.39455884,  0.44532225,
#         0.29845047,  0.14886339,  0.82861575,  0.37131879,  0.44190677,
#         0.99038224,  0.37171961,  0.29853548,  0.62499323,  0.62731579,
#         0.6359997 ,  0.24339792,  0.53799571,  0.60957707,  0.55472043,
#         0.52510799,  0.51694199,  0.73967319,  0.79887447,  0.69592578,
#         0.658725  ,  0.6306494 ,  0.5372272 ,  0.71386065,  0.50636057,
#         0.28837218,  0.53767895,  0.63135555,  0.59775181,  0.68395994,
#         0.67130005,  0.56496963,  0.54134413,  0.54639066,  0.52871384,
#         0.51205112,  0.48674025,  0.64077848,  0.44001826,  0.45086168,
#         0.35531745,  0.59822853,  0.35224422,  0.46255074,  0.53551528,
#         0.68613002,  0.76636651,  0.51095035,  0.54956664,  0.29348549,
#         0.72493356,  0.14202517,  0.23930025,  0.48386816,  0.30993162,
#         0.30954505,  0.61354042,  0.35180759,  0.33148836,  0.26460169])

# %%
sns.histplot(s,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ## OTHER DISTRIBUTION
# **LOG NORMAL DISTRIBUTION**

# %%
mu, sigma = 3. ,1. # mean and standard deviation
# Create a normal distribution
s = np.random.lognormal(mu, sigma, 1000)

# %%
sns.histplot(s,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(np.log(s),kde=True)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ## CHECK WHETEHR THE DISTRIBUTION IS NORMAL DISTRIBUTON

# %%
## if you wnat to check whethet the feature is guassian or normal distribution
## Q-Q plot
import matplotlib.pyplot as plt
from scipy import stats
import pylab    
def plot_data(sample):                                    ## plot the data and Q-Q plot of the data
    plt.figure(figsize=(10, 6))                           ## create a figure with size 10x6 
    plt.subplot(1, 2, 1)                                  ## create a subplot with 1 row and 2 columns
    sns.histplot(sample)                                  ## plot the histogram
    plt.subplot(1, 2, 2)                                  ## create a subplot with 1 row and 2 columns
    stats.probplot(sample, dist="norm", plot=pylab)       ## plot the Q-Q plot
    plt.show()

# %%
## create a normal distribution data
s= np.random.normal(0.5,0.2,1000)
plot_data(s)  ##  output give straight line that means it is normal distribution

# %%
def plot_data_log(sample):                                    ## plot the data and Q-Q plot of the data
    plt.figure(figsize=(10, 6))                           ## create a figure with size 10x6 
    plt.subplot(1, 2, 1)                                  ## create a subplot with 1 row and 2 columns
    sns.histplot(sample)                                  ## plot the histogram
    plt.subplot(1, 2, 2)                                  ## create a subplot with 1 row and 2 columns
    stats.probplot(np.log(sample), dist="norm", plot=pylab)       ## plot the Q-Q plot
    plt.show()

# %%
plot_data_log(s)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4688\4143437343.py:6: RuntimeWarning: invalid value encountered in log
#   stats.probplot(np.log(sample), dist="norm", plot=pylab)       ## plot the Q-Q plot

# %% [markdown]
# ## PEARSON AND SPERMAN RANK CORRELATION COEFFICIENTS

# %%
df = sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import pandas as pd

# %%
df=df.drop("day",axis=1).drop("sex",axis=1).drop("time",axis=1)

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000
